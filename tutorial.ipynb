# %% [markdown]
# ## Edit pyproject configurations
#
# ### Use your exact project name
#
# 1. Replace `project.name`
# 2. Replace `project.scripts.data-research`
# 3. Rename `src/data_research`

# %% [markdown]
# ## Clean your notebooks
#
# This workflow will automatically clean all your `notebooks/`'s outputs and convert them into a corresponding `.py` file (in [percent-format](https://github.com/mwouts/jupytext$text-notebooks)) every time you commit.
#
# NOTE: only notebook under `notebooks/` will be include, the others, such as this tutorial, are not under control.

# %%
# Make sure to install the dependencies and run the pre-commit hooks
# !uv sync

# %%
# !nbstripout --install
# !nbdime config-git --enable
# !pre-commit install
# !pre-commit run --all-files
